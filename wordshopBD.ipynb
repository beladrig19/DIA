# %%
# step 1

#dictionnaire vide client1
client1 = {}

# %%
# step 2

#dictionnaire vide client1
client1 = {}

#liste pour les attibu ad inserer dans le dictionnaire apres la boucle
donne_a_recuperer = ["nom", "prenom", "sexe", "solde"]  

#boucle pour recuperer donne client
for i in range(4):
    client1.update({donne_a_recuperer[i] : input(donne_a_recuperer[i])})
  
       
print(client1)

# %%
# step 3

#dictionnaire vide client1
client1 = {}

#liste pour les attibu ad inserer dans le dictionnaire apres la boucle
donne_a_recuperer = ["nom", "prenom", "sexe", "solde"]  

#boucle pour recuperer donne client
for i in range(4):
    client1.update({donne_a_recuperer[i] : input(donne_a_recuperer[i])})
  
       
print(client1)   

#liste de 12 autre dictionnaire (client)
liste_client = []
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 11
#       9 #boucle pour recuperer donne client
#      10 for i in range(4):
# ---> 11     client1.update({donne_a_recuperer[i] : input()})
#      14 print(client1)
#      16 #liste de 12 autre dictionnaire (client)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# step 4

#dictionnaire vide client1
client1 = {}

#liste pour les attibu ad inserer dans le dictionnaire apres la boucle
donne_a_recuperer = ["nom", "prenom", "sexe", "solde"]  

#boucle pour recuperer donne client
for i in range(4):
    client1.update({donne_a_recuperer[i] : input(donne_a_recuperer[i])})
  
       
print(client1)   

#liste de 12 autre dictionnaire (client)
liste_client = [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]

#boucle pour recuperer les donnes de touts les  autres 12 clients
for client in liste_client:
    for attribut in donne_a_recuperer:
        client.update({attribut : input(attribut)})
print(liste_client)
# Out:
# nomzhjd
# prenomeded
# sexeedhed
# soldeehed
# {'nom': 'zhjd', 'prenom': 'eded', 'sexe': 'edhed', 'solde': 'ehed'}
# nomfz
# prenomzr
# sexerf
# soldezf
# nomzrf
# prenomrz
# sexefv
# solder
# nomzv
# prenomr
# sexev
# soldeerv
# nomr
# prenomver
# sexev
# soldeer
# nomv
# prenom
# sexeerv
# solder
# nomve
# prenomrv
# sexeer
# soldevr
# nomv
# prenomrv
# sexere
# soldeer
# nomvre
# prenomvr
# sexev
# solderev
# nomrv
# prenomer
# sexevr
# soldev
# nomer
# prenomv
# sexere
# soldeer
# nomv
# prenomv
# sexeerv
# solderv
# nomr
# prenomvr
# sexev
# soldere
# [{'nom': 'fz', 'prenom': 'zr', 'sexe': 'rf', 'solde': 'zf'}, {'nom': 'zrf', 'prenom': 'rz', 'sexe': 'fv', 'solde': 'r'}, {'nom': 'zv', 'prenom': 'r', 'sexe': 'v', 'solde': 'erv'}, {'nom': 'r', 'prenom': 'ver', 'sexe': 'v', 'solde': 'er'}, {'nom': 'v', 'prenom': '', 'sexe': 'erv', 'solde': 'r'}, {'nom': 've', 'prenom': 'rv', 'sexe': 'er', 'solde': 'vr'}, {'nom': 'v', 'prenom': 'rv', 'sexe': 're', 'solde': 'er'}, {'nom': 'vre', 'prenom': 'vr', 'sexe': 'v', 'solde': 'rev'}, {'nom': 'rv', 'prenom': 'er', 'sexe': 'vr', 'solde': 'v'}, {'nom': 'er', 'prenom': 'v', 'sexe': 're', 'solde': 'er'}, {'nom': 'v', 'prenom': 'v', 'sexe': 'erv', 'solde': 'rv'}, {'nom': 'r', 'prenom': 'vr', 'sexe': 'v', 'solde': 're'}]

# %% [raw]
# liste_client[3]["solde"] -= 500

# %%
# step 5

#dictionnaire vide client1
client1 = {}

#liste pour les attibu ad inserer dans le dictionnaire apres la boucle
donne_a_recuperer = ["nom", "prenom", "sexe", "solde"]  

#boucle pour recuperer donne client
for i in range(4):
    client1.update({donne_a_recuperer[i] : input(donne_a_recuperer[i])})
  
       
print(client1)   

#liste de 12 autre dictionnaire (client)
liste_client = [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]

#boucle pour recuperer les donnes de touts les  autres 12 clients
for client in liste_client:
    for attribut in donne_a_recuperer:
        client.update({attribut : input(attribut)})
print(liste_client)

#ecrire un bloc pour effectuer un retrait de 500 euros pour le client4
liste_client[3]["solde"] = int(liste_client[3]["solde"]) - 500
# Out:
# nomagu
# prenompatrick
# sexemale
# solde10000
# {'nom': 'agu', 'prenom': 'patrick', 'sexe': 'male', 'solde': '10000'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 22
#      20 for client in liste_client:
#      21     for attribut in donne_a_recuperer:
# ---> 22         client.update({attribut : input(attribut)})
#      23 print(liste_client)
#      25 #ecrire un bloc pour effectuer un retrait de 500 euros pour le client4
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# step 6

#dictionnaire vide client1
client1 = {}

#liste pour les attibu ad inserer dans le dictionnaire apres la boucle
donne_a_recuperer = ["nom", "prenom", "sexe", "solde"]  

#boucle pour recuperer donne client
for i in range(4):
    client1.update({donne_a_recuperer[i] : input(donne_a_recuperer[i])})
  
       
print(client1)   

#liste de 12 autre dictionnaire (client)
liste_client = [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]

#boucle pour recuperer les donnes de touts les  autres 12 clients
for client in liste_client:
    for attribut in donne_a_recuperer:
        client.update({attribut : input(attribut)})
print(liste_client)

#ecrire un bloc pour effectuer un retrait de 500 euros pour le client4
liste_client[3]["solde"] = int(liste_client[3]["solde"]) - 500

#ecrire une bloc pour afficher le solde total
solde_total = sum(int(client["solde"]) for client in liste_clients)
print(f"Le solde total de tous les clients est: {solde_total}")

# %%
# step 7

#dictionnaire vide client1
client1 = {}

#liste pour les attibu ad inserer dans le dictionnaire apres la boucle
donne_a_recuperer = ["nom", "prenom", "sexe", "solde"]  

#boucle pour recuperer donne client
for i in range(4):
    client1.update({donne_a_recuperer[i] : input(donne_a_recuperer[i])})
  
       
print(client1)   

#liste de 12 autre dictionnaire (client)
liste_client = [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]

#boucle pour recuperer les donnes de touts les  autres 12 clients
for client in liste_client:
    for attribut in donne_a_recuperer:
        client.update({attribut : input(attribut)})
print(liste_client)

#ecrire un bloc pour effectuer un retrait de 500 euros pour le client4
liste_client[3]["solde"] = int(liste_client[3]["solde"]) - 500

#ecrire une bloc pour afficher le solde total
solde_total = sum(int(client["solde"]) for client in liste_clients)
print(f"Le solde total de tous les clients est: {solde_total}")

#ecrire un bloc pour compter le nombre de clients feminins et masculins

hommes = 0
femmes = 0

for client in list_client:
        if client["sexe"] == male:
            homme += 1
        else:
            femme += 1
print("le nombre de femmes est : " femmes) 
print("le nombre de hommes est : " hommes)

# %%
# step 8

#dictionnaire vide client1
client1 = {}

#liste pour les attibu ad inserer dans le dictionnaire apres la boucle
donne_a_recuperer = ["nom", "prenom", "sexe", "solde"]  

#boucle pour recuperer donne client
for i in range(4):
    client1.update({donne_a_recuperer[i] : input(donne_a_recuperer[i])})
  
       
print(client1)   

#liste de 12 autre dictionnaire (client)
liste_client = [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]

#boucle pour recuperer les donnes de touts les  autres 12 clients
for client in liste_client:
    for attribut in donne_a_recuperer:
        client.update({attribut : input(attribut)})
print(liste_client)

#ecrire un bloc pour effectuer un retrait de 500 euros pour le client4
liste_client[3]["solde"] = int(liste_client[3]["solde"]) - 500

#ecrire une bloc pour afficher le solde total
solde_total = sum(int(client["solde"]) for client in liste_clients)
print(f"Le solde total de tous les clients est: {solde_total}")

#ecrire un bloc pour compter le nombre de clients feminins et masculins

hommes = 0
femmes = 0

for client in list_client:
        if client["sexe"] == male:
            homme += 1
        else:
            femme += 1
print("le nombre de femmes est : " femmes) 
print("le nombre de hommes est : " hommes)

#un nuveau client Bassam Kurdy avec un solde de 2000 euro, il faut l'ajoute dans la base de données 

for client in list_client:
    client.update({"nom" : "kurdy", "prenom" : "bassam", "sexe" : "male", "solde" : "2000"})
